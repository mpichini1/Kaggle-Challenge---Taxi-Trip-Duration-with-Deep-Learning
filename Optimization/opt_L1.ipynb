# %%
# %%capture
# !pip install git+https://github.com/optuna/optuna.git #installa la libreria optuna

# %%
import pandas as pd
import numpy as np
import math as mh

import seaborn as sns
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn import linear_model

from keras import *
import tensorflow as tf
from keras.models import Sequential
from keras.layers.core import Dense, Dropout
from tensorflow.keras import regularizers
from keras.optimizers import Adam, RMSprop
from keras.backend import clear_session

import optuna
from optuna.samplers import RandomSampler
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train = pd.read_csv("/content/drive/MyDrive/AML project/train_manipulated_integrated.csv")

# %%
y_train = train['trip_duration'].values.reshape(-1, 1)

X_train = train.drop(columns = ['trip_duration'])

X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size = 0.30,
                                                  random_state = 1234)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.15,
                                                  random_state = 1234)

# %%
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# (857057, 48)
# (151246, 48)
# (432130, 48)

# %%
#si separano le dummies dalle quantitative

X_train_to_stand = X_train[['passenger_count', 'distance',
                                            'maximum temperature', 'minimum temperature',
                                           'average temperature',
                                           'precipitation', 
                                           'snow fall',
                                           'snow depth', 'direction']]

X_train_not_stand = X_train.drop(columns = ['passenger_count', 'distance',
                                            'maximum temperature', 'minimum temperature',
                                           'average temperature',
                                           'precipitation', 
                                           'snow fall',
                                           'snow depth', 'direction']).values


X_val_to_stand = X_val[['passenger_count', 'distance',
                                            'maximum temperature', 'minimum temperature',
                                           'average temperature',
                                           'precipitation', 
                                           'snow fall',
                                           'snow depth', 'direction']]

X_val_not_stand = X_val.drop(columns = ['passenger_count', 'distance',
                                            'maximum temperature', 'minimum temperature',
                                           'average temperature',
                                           'precipitation', 
                                           'snow fall',
                                           'snow depth', 'direction']).values

X_test_to_stand = X_test[['passenger_count', 'distance',
                                            'maximum temperature', 'minimum temperature',
                                           'average temperature',
                                           'precipitation', 
                                           'snow fall',
                                           'snow depth', 'direction']]

X_test_not_stand = X_test.drop(columns = ['passenger_count', 'distance',
                                            'maximum temperature', 'minimum temperature',
                                           'average temperature',
                                           'precipitation', 
                                           'snow fall',
                                           'snow depth', 'direction']).values

# %%
scaler = StandardScaler()

X_train_stand = scaler.fit_transform(X_train_to_stand)
y_train_stand = scaler.fit(y_train).transform(y_train)

X_val_stand = scaler.fit(X_train_to_stand).transform(X_val_to_stand)
y_val_stand = scaler.fit(y_train).transform(y_val)

X_test_stand = scaler.fit(X_train_to_stand).transform(X_test_to_stand)
y_test_stand = scaler.fit(y_train).transform(y_test)

# %%
X_train = np.concatenate((X_train_stand, X_train_not_stand), axis = 1)
X_val = np.concatenate((X_val_stand, X_val_not_stand), axis = 1)
X_test = np.concatenate((X_test_stand, X_test_not_stand), axis = 1)

y_train = y_train_stand
y_val = y_val_stand
y_test = y_test_stand

# %%
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# (857057, 48)
# (151246, 48)
# (432130, 48)

# %%
print(y_train.shape)
print(y_val.shape)
print(y_test.shape)
# Out:
# (857057, 1)
# (151246, 1)
# (432130, 1)

# %%
### inizia l'ottimizzazione

es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=10, restore_best_weights=True)

def objective(trial): 
  clear_session()
  initializer = tf.keras.initializers.GlorotUniform(seed=1234) #inizializiamo i pesi

  es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', 
                                        patience=5, 
                                        restore_best_weights=True)
  opt = tf.keras.optimizers.SGD(learning_rate= 0.002, momentum=0.3, 
                              nesterov = False)

  callbacks_list = [optuna.integration.KerasPruningCallback(trial, 'val_loss'), 
                      es]

  n_hidden = trial.suggest_categorical("#hidden", [3, 4])

  if n_hidden == 3:
    units_1 = trial.suggest_int("dense1", 32, 256, step = 16)
    units_2 = trial.suggest_int("dense2", 32, 128, step = 16)
    units_3 = trial.suggest_int("dense3", 32, 128, step = 16)
    lambda_1 = trial.suggest_loguniform("lambda", 1e-4, 1e-1)
    activations = 'relu'

    model = Sequential()
    model.add(Dense(units_1, input_shape = (48,),
                  activation = activations, 
                  kernel_regularizer= regularizers.l1(lambda_1),
                  kernel_initializer=initializer))
    model.add(Dense(units_2,
                  activation = activations, 
                  kernel_regularizer= regularizers.l1(lambda_1),
                  kernel_initializer=initializer))
    model.add(Dense(units_3,
                  activation = activations, 
                  kernel_regularizer= regularizers.l1(lambda_1),
                  kernel_initializer=initializer))
    model.add(Dense(1,
                  activation = "linear", 
                  kernel_regularizer= regularizers.l1(lambda_1),
                  kernel_initializer=initializer))
  else:
    units_1 = trial.suggest_int("dense1", 32, 256, step = 16)
    units_2 = trial.suggest_int("dense2", 32, 128, step = 16)
    units_3 = trial.suggest_int("dense3", 32, 128, step = 16)
    units_4 = trial.suggest_int("dense4", 16, 64, step = 16)
    lambda_1 = trial.suggest_loguniform("lambda", 1e-4, 1e-1)
    activations = 'relu'

    model = Sequential()
    model.add(Dense(units_1, input_shape = (48,),
                  activation = activations, 
                  kernel_regularizer= regularizers.l1(lambda_1),
                  kernel_initializer=initializer))
    model.add(Dense(units_2,
                  activation = activations, 
                  kernel_regularizer= regularizers.l1(lambda_1),
                  kernel_initializer=initializer))
    model.add(Dense(units_3,
                  activation = activations, 
                  kernel_regularizer= regularizers.l1(lambda_1),
                  kernel_initializer=initializer))
    model.add(Dense(units_4,
                  activation = activations, 
                  kernel_regularizer= regularizers.l1(lambda_1),
                  kernel_initializer=initializer))
    model.add(Dense(1,
                  activation = "linear", 
                  kernel_regularizer= regularizers.l1(lambda_1),
                  kernel_initializer=initializer))
    
  model.compile(loss = "mse", optimizer=opt, metrics = [tf.keras.metrics.RootMeanSquaredError()])

  model.fit(X_train, y_train, epochs = 30, 
            batch_size = 128, validation_data=(X_val, y_val),
            shuffle = True,
            callbacks = callbacks_list,
            verbose=False)
  
  score = model.evaluate(X_val, y_val, verbose=0, batch_size = 128)

  return score[0]

# %%
sampler = RandomSampler(100) #facciamo la random seaerch che almeno la sappiamo spiegare

study = optuna.create_study(study_name = "l1_reg", direction="minimize", 
                            sampler = sampler, storage='sqlite:////content/drive/MyDrive/AML project/sqlite/l1_reg.db', 
                            load_if_exists=True)
# Out:
# [I 2021-01-13 10:19:50,263] A new study created in RDB with name: l1_reg

# %%
# %%time
# %%capture

study.optimize(objective, n_trials=50)
# Out:
# [I 2021-01-13 10:26:53,751] Trial 0 finished with value: 0.29965195059776306 and parameters: {'#hidden': 3, 'dense1': 160, 'dense2': 80, 'dense3': 32, 'lambda': 0.00027913514479844154}. Best is trial 0 with value: 0.29965195059776306.
# [I 2021-01-13 10:33:51,648] Trial 1 finished with value: 0.29114577174186707 and parameters: {'#hidden': 3, 'dense1': 64, 'dense2': 112, 'dense3': 64, 'lambda': 0.0004268971223779536}. Best is trial 1 with value: 0.29114577174186707.
# [I 2021-01-13 10:40:45,714] Trial 2 finished with value: 0.30613458156585693 and parameters: {'#hidden': 3, 'dense1': 48, 'dense2': 32, 'dense3': 32, 'lambda': 0.00015525411810181702}. Best is trial 1 with value: 0.29114577174186707.
# [I 2021-01-13 10:48:02,824] Trial 3 finished with value: 0.3219706416130066 and parameters: {'#hidden': 4, 'dense1': 224, 'dense2': 64, 'dense3': 32, 'dense4': 64, 'lambda': 0.0002114125046324832}. Best is trial 1 with value: 0.29114577174186707.
# [I 2021-01-13 10:52:42,220] Trial 4 finished with value: 0.5138676166534424 and parameters: {'#hidden': 3, 'dense1': 64, 'dense2': 80, 'dense3': 96, 'lambda': 0.027230113230823506}. Best is trial 1 with value: 0.29114577174186707.
# [I 2021-01-13 10:52:57,167] Trial 5 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 10:57:15,826] Trial 6 pruned. Trial was pruned at epoch 17.
# [I 2021-01-13 10:57:31,343] Trial 7 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 10:57:46,293] Trial 8 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:01:46,386] Trial 9 pruned. Trial was pruned at epoch 17.
# [I 2021-01-13 11:02:01,205] Trial 10 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:02:15,228] Trial 11 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:07:12,496] Trial 12 pruned. Trial was pruned at epoch 21.
# [I 2021-01-13 11:07:27,926] Trial 13 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:11:49,166] Trial 14 pruned. Trial was pruned at epoch 17.
# [I 2021-01-13 11:12:03,592] Trial 15 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:12:19,505] Trial 16 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:12:34,511] Trial 17 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:12:49,407] Trial 18 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:15:32,373] Trial 19 pruned. Trial was pruned at epoch 10.
# [I 2021-01-13 11:15:46,781] Trial 20 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:16:02,119] Trial 21 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:16:16,234] Trial 22 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:16:30,823] Trial 23 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:19:38,966] Trial 24 pruned. Trial was pruned at epoch 12.
# [I 2021-01-13 11:19:52,547] Trial 25 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:20:08,295] Trial 26 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:20:22,561] Trial 27 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:23:14,236] Trial 28 pruned. Trial was pruned at epoch 12.
# [I 2021-01-13 11:23:28,835] Trial 29 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:23:42,766] Trial 30 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:23:58,476] Trial 31 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:27:50,170] Trial 32 pruned. Trial was pruned at epoch 16.
# [I 2021-01-13 11:30:08,092] Trial 33 pruned. Trial was pruned at epoch 9.
# [I 2021-01-13 11:33:44,965] Trial 34 pruned. Trial was pruned at epoch 15.
# [I 2021-01-13 11:34:01,060] Trial 35 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:34:16,889] Trial 36 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:38:12,237] Trial 37 pruned. Trial was pruned at epoch 15.
# [I 2021-01-13 11:38:27,321] Trial 38 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:38:42,918] Trial 39 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:38:58,382] Trial 40 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:39:13,368] Trial 41 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:39:27,328] Trial 42 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:39:43,357] Trial 43 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:43:09,402] Trial 44 pruned. Trial was pruned at epoch 14.
# [I 2021-01-13 11:43:25,117] Trial 45 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:46:57,434] Trial 46 pruned. Trial was pruned at epoch 13.
# [I 2021-01-13 11:50:32,256] Trial 47 pruned. Trial was pruned at epoch 15.
# [I 2021-01-13 11:50:47,960] Trial 48 pruned. Trial was pruned at epoch 0.
# [I 2021-01-13 11:51:03,156] Trial 49 pruned. Trial was pruned at epoch 0.
# CPU times: user 1h 58min 46s, sys: 14min 14s, total: 2h 13min
# Wall time: 1h 31min 11s

# %%
print('Best trial number: ', study.best_trial.number)

print("Number of finished trials: {}".format(len(study.trials)))
trial = study.best_trial

print("  Value: {}".format(trial.value))
print('Best parameters: \n', study.best_trial.params)
# Out:
# Best trial number:  1
# Number of finished trials: 50
#   Value: 0.29114577174186707
# Best parameters:
#  {'#hidden': 3, 'dense1': 64, 'dense2': 112, 'dense3': 64, 'lambda': 0.0004268971223779536}

# %%
df_trials = study.trials_dataframe()

# %%
df_trials.to_csv("/content/drive/MyDrive/AML project/risultati_opt_l2_int.csv",
                 index = False)
