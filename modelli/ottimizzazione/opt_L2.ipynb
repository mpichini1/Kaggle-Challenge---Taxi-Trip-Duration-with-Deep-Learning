# %%
# %%capture
# !pip install git+https://github.com/optuna/optuna.git #installa la libreria optuna

# %%
import pandas as pd
import numpy as np
import math as mh

import seaborn as sns
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn import linear_model

from keras import *
import tensorflow as tf
from keras.models import Sequential
from keras.layers.core import Dense, Dropout
from tensorflow.keras import regularizers
from keras.optimizers import Adam, RMSprop
from keras.backend import clear_session

import optuna
from optuna.samplers import RandomSampler
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train = pd.read_csv("/content/drive/MyDrive/AML project/train_manipulated_integrated.csv")

# %%
y_train = train['trip_duration'].values.reshape(-1, 1)

X_train = train.drop(columns = ['trip_duration'])

X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size = 0.30,
                                                  random_state = 1234)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.15,
                                                  random_state = 1234)

# %%
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# (857057, 48)
# (151246, 48)
# (432130, 48)

# %%
#si separano le dummies dalle quantitative

X_train_to_stand = X_train[['passenger_count', 'distance',
                                            'maximum temperature', 'minimum temperature',
                                           'average temperature',
                                           'precipitation', 
                                           'snow fall',
                                           'snow depth', 'direction']]

X_train_not_stand = X_train.drop(columns = ['passenger_count', 'distance',
                                            'maximum temperature', 'minimum temperature',
                                           'average temperature',
                                           'precipitation', 
                                           'snow fall',
                                           'snow depth', 'direction']).values


X_val_to_stand = X_val[['passenger_count', 'distance',
                                            'maximum temperature', 'minimum temperature',
                                           'average temperature',
                                           'precipitation', 
                                           'snow fall',
                                           'snow depth', 'direction']]

X_val_not_stand = X_val.drop(columns = ['passenger_count', 'distance',
                                            'maximum temperature', 'minimum temperature',
                                           'average temperature',
                                           'precipitation', 
                                           'snow fall',
                                           'snow depth', 'direction']).values

X_test_to_stand = X_test[['passenger_count', 'distance',
                                            'maximum temperature', 'minimum temperature',
                                           'average temperature',
                                           'precipitation', 
                                           'snow fall',
                                           'snow depth', 'direction']]

X_test_not_stand = X_test.drop(columns = ['passenger_count', 'distance',
                                            'maximum temperature', 'minimum temperature',
                                           'average temperature',
                                           'precipitation', 
                                           'snow fall',
                                           'snow depth', 'direction']).values

# %%
scaler = StandardScaler()

X_train_stand = scaler.fit_transform(X_train_to_stand)
y_train_stand = scaler.fit(y_train).transform(y_train)

X_val_stand = scaler.fit(X_train_to_stand).transform(X_val_to_stand)
y_val_stand = scaler.fit(y_train).transform(y_val)

X_test_stand = scaler.fit(X_train_to_stand).transform(X_test_to_stand)
y_test_stand = scaler.fit(y_train).transform(y_test)

# %%
X_train = np.concatenate((X_train_stand, X_train_not_stand), axis = 1)
X_val = np.concatenate((X_val_stand, X_val_not_stand), axis = 1)
X_test = np.concatenate((X_test_stand, X_test_not_stand), axis = 1)

y_train = y_train_stand
y_val = y_val_stand
y_test = y_test_stand

# %%
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# (857057, 48)
# (151246, 48)
# (432130, 48)

# %%
print(y_train.shape)
print(y_val.shape)
print(y_test.shape)
# Out:
# (857057, 1)
# (151246, 1)
# (432130, 1)

# %%
### inizia l'ottimizzazione

es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=10, restore_best_weights=True)

def objective(trial): 
  clear_session()
  initializer = tf.keras.initializers.GlorotUniform(seed=1234) #inizializiamo i pesi

  es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', 
                                        patience=5, 
                                        restore_best_weights=True)
  opt = tf.keras.optimizers.SGD(learning_rate= 0.002, momentum=0.3, 
                              nesterov = False)

  callbacks_list = [optuna.integration.KerasPruningCallback(trial, 'val_loss'), 
                      es]

  n_hidden = trial.suggest_categorical("#hidden", [3, 4])

  if n_hidden == 3:
    units_1 = trial.suggest_int("dense1", 32, 256, step = 16)
    units_2 = trial.suggest_int("dense2", 32, 128, step = 16)
    units_3 = trial.suggest_int("dense3", 32, 128, step = 16)
    lambda_1 = trial.suggest_loguniform("lambda", 1e-4, 1e-1)
    activations = 'relu'

    model = Sequential()
    model.add(Dense(units_1, input_shape = (48,),
                  activation = activations, 
                  kernel_regularizer= regularizers.l2(lambda_1),
                  kernel_initializer=initializer))
    model.add(Dense(units_2,
                  activation = activations, 
                  kernel_regularizer= regularizers.l2(lambda_1),
                  kernel_initializer=initializer))
    model.add(Dense(units_3,
                  activation = activations, 
                  kernel_regularizer= regularizers.l2(lambda_1),
                  kernel_initializer=initializer))
    model.add(Dense(1,
                  activation = "linear", 
                  kernel_regularizer= regularizers.l2(lambda_1),
                  kernel_initializer=initializer))
  else:
    units_1 = trial.suggest_int("dense1", 32, 256, step = 16)
    units_2 = trial.suggest_int("dense2", 32, 128, step = 16)
    units_3 = trial.suggest_int("dense3", 32, 128, step = 16)
    units_4 = trial.suggest_int("dense4", 16, 64, step = 16)
    lambda_1 = trial.suggest_loguniform("lambda", 1e-4, 1e-1)
    activations = 'relu'

    model = Sequential()
    model.add(Dense(units_1, input_shape = (48,),
                  activation = activations, 
                  kernel_regularizer= regularizers.l2(lambda_1),
                  kernel_initializer=initializer))
    model.add(Dense(units_2,
                  activation = activations, 
                  kernel_regularizer= regularizers.l2(lambda_1),
                  kernel_initializer=initializer))
    model.add(Dense(units_3,
                  activation = activations, 
                  kernel_regularizer= regularizers.l2(lambda_1),
                  kernel_initializer=initializer))
    model.add(Dense(units_4,
                  activation = activations, 
                  kernel_regularizer= regularizers.l2(lambda_1),
                  kernel_initializer=initializer))
    model.add(Dense(1,
                  activation = "linear", 
                  kernel_regularizer= regularizers.l2(lambda_1),
                  kernel_initializer=initializer))
    
  model.compile(loss = "mse", optimizer=opt, metrics = [tf.keras.metrics.RootMeanSquaredError()])

  model.fit(X_train, y_train, epochs = 30, 
            batch_size = 128, validation_data=(X_val, y_val),
            shuffle = True,
            callbacks = callbacks_list,
            verbose=False)
  
  score = model.evaluate(X_val, y_val, verbose=0, batch_size = 128)

  return score[0]

# %%
sampler = RandomSampler(123) #facciamo la random seaerch che almeno la sappiamo spiegare

study = optuna.create_study(study_name = "L2_Reg", direction="minimize", 
                            sampler = sampler, storage='sqlite:////content/drive/MyDrive/AML project/sqlite/L2_Reg.db', 
                            load_if_exists=True)
# Out:
# [I 2021-01-12 20:22:52,907] A new study created in RDB with name: L2_Reg

# %%
# %%capture

study.optimize(objective, n_trials=50)
# Out:
# [I 2021-01-12 20:30:23,858] Trial 0 finished with value: 0.31144091486930847 and parameters: {'#hidden': 3, 'dense1': 240, 'dense2': 128, 'dense3': 64, 'lambda': 0.0004792414358623592}. Best is trial 0 with value: 0.31144091486930847.
# [I 2021-01-12 20:37:39,068] Trial 1 finished with value: 0.291975736618042 and parameters: {'#hidden': 3, 'dense1': 48, 'dense2': 80, 'dense3': 64, 'lambda': 0.0018591711878786364}. Best is trial 1 with value: 0.291975736618042.
# [I 2021-01-12 20:44:57,817] Trial 2 finished with value: 0.29847198724746704 and parameters: {'#hidden': 3, 'dense1': 48, 'dense2': 32, 'dense3': 48, 'lambda': 0.002772015819815351}. Best is trial 1 with value: 0.291975736618042.
# [I 2021-01-12 20:52:54,189] Trial 3 finished with value: 0.2920242249965668 and parameters: {'#hidden': 4, 'dense1': 32, 'dense2': 128, 'dense3': 32, 'dense4': 64, 'lambda': 0.0009385397696776552}. Best is trial 1 with value: 0.291975736618042.
# [I 2021-01-12 21:00:14,898] Trial 4 finished with value: 0.3304617702960968 and parameters: {'#hidden': 3, 'dense1': 240, 'dense2': 96, 'dense3': 32, 'lambda': 0.006049328919866826}. Best is trial 1 with value: 0.291975736618042.
# [I 2021-01-12 21:00:31,894] Trial 5 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 21:00:47,626] Trial 6 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 21:01:04,824] Trial 7 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 21:02:19,543] Trial 8 pruned. Trial was pruned at epoch 4.
# [I 2021-01-12 21:02:35,092] Trial 9 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 21:02:50,615] Trial 10 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 21:03:07,410] Trial 11 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 21:03:23,147] Trial 12 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 21:03:39,673] Trial 13 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 21:03:55,933] Trial 14 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 21:04:11,982] Trial 15 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 21:12:05,857] Trial 16 finished with value: 0.2766621708869934 and parameters: {'#hidden': 4, 'dense1': 80, 'dense2': 96, 'dense3': 112, 'dense4': 32, 'lambda': 0.0001069724762095448}. Best is trial 16 with value: 0.2766621708869934.
# [I 2021-01-12 21:12:22,848] Trial 17 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 21:12:39,506] Trial 18 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 21:19:13,007] Trial 19 pruned. Trial was pruned at epoch 24.
# [I 2021-01-12 21:26:38,290] Trial 20 finished with value: 0.29013800621032715 and parameters: {'#hidden': 3, 'dense1': 80, 'dense2': 48, 'dense3': 128, 'lambda': 0.00038253297826090787}. Best is trial 16 with value: 0.2766621708869934.
# [I 2021-01-12 21:32:41,342] Trial 21 pruned. Trial was pruned at epoch 21.
# [I 2021-01-12 21:32:56,919] Trial 22 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 21:35:24,358] Trial 23 pruned. Trial was pruned at epoch 9.
# [I 2021-01-12 21:35:40,957] Trial 24 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 21:35:58,168] Trial 25 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 21:40:09,907] Trial 26 pruned. Trial was pruned at epoch 16.
# [I 2021-01-12 21:48:21,307] Trial 27 finished with value: 0.2743085026741028 and parameters: {'#hidden': 4, 'dense1': 224, 'dense2': 80, 'dense3': 128, 'dense4': 16, 'lambda': 0.00010289728794436796}. Best is trial 27 with value: 0.2743085026741028.
# [I 2021-01-12 21:48:37,150] Trial 28 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 21:55:55,417] Trial 29 finished with value: 0.2860086262226105 and parameters: {'#hidden': 3, 'dense1': 176, 'dense2': 32, 'dense3': 32, 'lambda': 0.0005279194868024993}. Best is trial 27 with value: 0.2743085026741028.
# [I 2021-01-12 21:56:12,827] Trial 30 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 21:56:30,380] Trial 31 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 21:56:44,683] Trial 32 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 21:57:01,150] Trial 33 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 21:57:16,986] Trial 34 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 22:04:35,746] Trial 35 finished with value: 0.27240511775016785 and parameters: {'#hidden': 3, 'dense1': 144, 'dense2': 112, 'dense3': 48, 'lambda': 0.00010187419587125717}. Best is trial 35 with value: 0.27240511775016785.
# [I 2021-01-12 22:04:51,823] Trial 36 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 22:05:06,673] Trial 37 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 22:05:22,847] Trial 38 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 22:07:15,872] Trial 39 pruned. Trial was pruned at epoch 6.
# [I 2021-01-12 22:07:33,255] Trial 40 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 22:07:51,488] Trial 41 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 22:08:08,776] Trial 42 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 22:15:33,875] Trial 43 finished with value: 0.28037992119789124 and parameters: {'#hidden': 3, 'dense1': 176, 'dense2': 64, 'dense3': 112, 'lambda': 0.00015947128895686284}. Best is trial 35 with value: 0.27240511775016785.
# [I 2021-01-12 22:15:49,815] Trial 44 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 22:16:05,319] Trial 45 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 22:16:22,438] Trial 46 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 22:16:39,366] Trial 47 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 22:16:55,330] Trial 48 pruned. Trial was pruned at epoch 0.
# [I 2021-01-12 22:17:12,654] Trial 49 pruned. Trial was pruned at epoch 0.

# %%
print('Best trial number: ', study.best_trial.number)

print("Number of finished trials: {}".format(len(study.trials)))
trial = study.best_trial

print("  Value: {}".format(trial.value))
print('Best parameters: \n', study.best_trial.params)
# Out:
# Best trial number:  35
# Number of finished trials: 50
#   Value: 0.27240511775016785
# Best parameters:
#  {'#hidden': 3, 'dense1': 144, 'dense2': 112, 'dense3': 48, 'lambda': 0.00010187419587125717}

# %%
df_trials = study.trials_dataframe()

# %%
df_trials.to_csv("/content/drive/MyDrive/AML project/risultati_opt_l2_int.csv",
                 index = False)

# %%
# Out:
# array([[-0.40599321],
#        [-0.79515114],
#        [ 0.46131613],
#        ...,
#        [-0.39392629],
#        [-0.58398017],
#        [-0.65638164]])
